# %% [markdown]
# # Машинное обучение, ВМК МГУ
#
# ## Практическое задание 2. Exploratory Data Analysis и линейная регрессия
#
# ### Общая информация
# Дата выдачи: 08.10.2021
#
# Мягкий дедлайн: 23:59MSK 22.10.2021
#
# Жесткий дедлайн: 23:59MSK 29.10.2021

# %% [markdown]
# ### О задании
# В этом задании мы попытаемся научиться анализировать данные и выделять из них полезные признаки. Мы также будем использовать `seaborn` и научимся `sklearn`, а заодно привыкнем к основным понятиям машинного обучения.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — **12 баллов + 4.8 бонусов**. Проверяющий имеет право снизить оценку за неэффективную реализацию или неопрятные графики.
#
# **Обратите внимание**, что в каждом разделе домашнего задания есть оцениваниемые задачи и есть вопросы. Вопросы дополняют задачи и направлены на то, чтобы проинтерпретировать или обосновать происходящее. Код без интерпретации не имеет смысла, поэтому отвечать на вопросы обязательно — за отсутствие ответов мы будем снижать баллы за задачи. Если вы ответите на вопросы, но не напишете корректный код к соответствующим оцениваемым задачам, то баллы за такое выставлены не будут.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# <p style="color:#de3815;font-size:25px;">
# Напоминание об оформлении и выполнении ноутбука
# </p>
#
# * Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть, не запуская ячейки (кроме редких случаев, когда необходимо намеренно скрыть ненужный output, про такие случаи желательно писать пояснения в тексте). **В противном случае -1 балл**
# * При оформлении ДЗ нужно пользоваться данным файлом в качестве шаблона. **Не нужно** удалять и видоизменять написанный код и текст, если явно не указана такая возможность. Создавать новые ячейки с кодом/текстов там, где это осмысленно и вы считаете необходимым, конечно, можно. **В противном случае -1 балл**
# * В anytask обязательно нужно прикреплять отдельно файл с расширением ipynb (не в архиве, а именно отдельно). Если необходимо отправить еще какие-то файлы, то вынесите их в отдельный архив (если файлов много) и пришлите. **В противном случае -0.5 балла**
# ---
# * Пишите, пожалуйста, выводы и ответы на вопросы в текстовых ячейках/при помощи print в коде/как результат вывода ячейки. При их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и **поэтому будем снижать баллы**
# * Если алгоритм не сказано реализовывать явно, его всегда можно импортировать из библиотеки.
# ---
# * Про графики. _Штрафы будут применяться к каждому результату команды отображения графика (plt.show() и др. аналогичные). Исключением являются графики, генерируемые функциями каких-либо сторонних библиотек, если их нельзя кастомизировать_
#
#     * должно быть название (plt.title) графика; **В противном случае &ndash; -0.05 балла**
#     * на графиках должны быть подписаны оси (plt.xlabel, plt.ylabel); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * должны быть подписаны единицы измерения (если это возможно); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * все названия должны быть понятны любому человеку, знакомому с терминологией, без заглядывания в код; **В противном случае &ndash; -0.05 балла**
#     * подписи тиков на осях не должны сливаться как на одной оси, так и между ними; **В противном случае &ndash; -0.025 балла за каждую ось**
#     * если изображено несколько сущностей на одном холсте (например несколько функций), то необходима поясняющая легенда (plt.legend); **В противном случае &ndash; -0.05 балла**
#     * все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном); **В противном случае &ndash; -0.05 балла**
#     * если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
#     * графики должны быть не супер-микро и не супер-макро по размерам, так, чтобы можно было увидеть все, что нужно.
#     * при необходимости улучшения наглядности графиков, можно пользоваться логарифмической шкалой по осям x/y.
#
# ### А также..
#
# * Для удобства поиска вопросов, на которые от вас просят ответа, мы пометили их знаком **(?)**
# * Знак **(!)** означает, что выполнение замечания необходимо для **возможности получения полного балла**
# * Даем до +0.5 баллов за выдающиеся успехи по субъективному мнению проверяющих. Этот **бонус** не апеллируется

# %% [markdown]
# В этом ноутбуке используется библиотека `folium` для визуализации карт. Она работает в google colab!

# %%
# !pip3 install folium

# %%
import folium

m = folium.Map(location=(55.7522200, 37.6155600), zoom_start=10)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Если вы всё сделали правильно, то выше должна открыться карта Москвы.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style="darkgrid")

# %% [markdown]
# ## Часть 0. Подготовка (1 балл)

# %% [markdown]
# **Задание 1 (1 балл)**.
#
# Мы будем работать с данными из соревнования [New York City Taxi Trip Duration](https://www.kaggle.com/c/nyc-taxi-trip-duration/overview), в котором нужно было предсказать длительность поездки на такси. Скачайте обучающую выборку из этого соревнования и загрузите ее:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
data_train = pd.read_csv('train.csv')

# %% [markdown]
# **(0.1 балл)** Обратите внимание на колонки `pickup_datetime` и `dropoff_datetime`. `dropoff_datetime` был добавлена организаторами только в обучающую выборку, то есть использовать эту колонку нельзя, давайте удалим ее. В `pickup_datetime` записаны дата и время начала поездки. Чтобы с ней было удобно работать, давайте преобразуем даты в `datetime`-объекты

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
data_train = data_train.drop(columns=['dropoff_datetime'])
data_train.pickup_datetime = pd.to_datetime(data_train.pickup_datetime)
data_train
# Out:
#                 id  vendor_id     pickup_datetime  passenger_count  \
# 0        id2875421          2 2016-03-14 17:24:55                1
# 1        id2377394          1 2016-06-12 00:43:35                1
# 2        id3858529          2 2016-01-19 11:35:24                1
# 3        id3504673          2 2016-04-06 19:32:31                1
# 4        id2181028          2 2016-03-26 13:30:55                1
# ...            ...        ...                 ...              ...
# 1458639  id2376096          2 2016-04-08 13:31:04                4
# 1458640  id1049543          1 2016-01-10 07:35:15                1
# 1458641  id2304944          2 2016-04-22 06:57:41                1
# 1458642  id2714485          1 2016-01-05 15:56:26                1
# 1458643  id1209952          1 2016-04-05 14:44:25                1
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0              -73.982155        40.767937         -73.964630
# ...

# %% [markdown]
# **(0.2 балла)** В колонке `trip_duration` записано целевое значение, которое мы хотим предсказывать. Давайте посмотрим на распределение таргета в обучающей выборке. Для этого нарисуйте его гистограмму:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
plt.figure(figsize=(10,7))
plt.title('Распределение таргета в обучающей выборке', fontsize=15)

plt.hist(data_train.trip_duration, edgecolor='black')

plt.xlabel('Длительность поездки, сек',  fontsize=15)
plt.ylabel('Количество поездок',  fontsize=15)
plt.grid(True) 
plt.show()

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)**Что можно сказать о целевой переменной по гистограмме её значений?

# %% [markdown]
# **Ответ**:
# Целевая переменная больше всего принимает значений в пределах от $0$ до $0.3*10^6$. Но есть какие-то отдельные объекты, которые принимают значения не из данного диапозона и их по сравнению с остальными очень мало.

# %% [markdown]
# В соревновании в качестве метрики качества использовалось RMSLE:
# $$\text{RMSLE}(X, y, a) = \sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\log{(y_i + 1)} - \log{(a(x_i) + 1)}\big)^2}$$
#
# **Вопрос (0.1 балл)**: **(?)**Как вы думаете, почему авторы соревнования выбрали именно RMSLE, а не RMSE?
#
# **Ответ**:
# Из графика видно, что диапозон значений целевой перменной сильно разбросаны, есть выбросы. Если разница значений между реальным значением и предсказанным большая, то RMSE сильно возрастает в отличии от RMSLE. Так как
# $$\log{(y_i + 1)} - \log{(a(x_i) + 1)} =\log {\frac{y_i + 1}{a(x_i) + 1}},$$
# то RMSLE считает относительную ошибку, поэтому выбросы не так сильно влияют на модель по сравнению с RMSE.

# %% [markdown]
# На семинаре мы рассматривали несколько моделей линейной регрессии в `sklearn`, но каждая из них оптимизировала среднеквадратичную ошибку (MSE), а не RMSLE. Давайте проделаем следующий трюк: будем предсказывать не целевую переменную, а ее *логарифм*. Обозначим $\hat{y}_i = \log{(y_i + 1)}$ — модифицированный таргет, а $\hat{a}(x_i)$ — предсказание модели, которая обучалась на $\hat{y}_i$, то есть логарифм таргета. Чтобы предсказать исходное значение, мы можем просто взять экспоненту от нашего предсказания: $a(x_i) = \exp(\hat{a}(x_i)) - 1$.
#
# **Вопрос (0.3 балла)**: **(?)**Покажите, что оптимизация RMSLE для модели $a$ эквивалентна оптимизации MSE для модели $\hat{a}$.
#
# **Доказательство**: Напишие прямо тут в ячейке, при необходимости использовав синтаксис LaTeX в ячейке
#
# ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ $$\text{RMSLE}(X, y, a) =\sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\log{(y_i + 1)} - \log{(a(x_i) + 1)}\big)^2} = \{\text{подставим значения } a(x_i) = \exp(\hat{a}(x_i)) - 1, y_i = \exp(\hat{y}(x_i)) - 1\} = \sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\log{((\exp(\hat{y}(x_i)) - 1 + 1\big)} - \log{(\exp(\hat{a}(x_i)) - 1 + 1)})\big)^2} = \sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\hat{y}(x_i) - \hat{a}(x_i)\big)^2} = \text{RMSE}(X, \hat{y}, \hat{a}) $$

# %% [markdown]
# **(0.1 балл)** Итак, мы смогли свести задачу оптимизации RMSLE к задаче оптимизации MSE, которую мы умеем решать! Кроме того, у логарифмирования таргета есть еще одно полезное свойство. Чтобы его увидеть, добавьте к нашей выборке колонку `log_trip_duration` (воспользуйтесь `np.log1p`) и нарисуйте гистограмму модифицированного таргета по обучающей выборке. Удалите колонку со старым таргетом.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
log_trip_duration = np.log1p(data_train.trip_duration)
data_train['log_trip_duration'] = log_trip_duration
data_train = data_train.drop(columns=['trip_duration'])
data_train
# Out:
#                 id  vendor_id     pickup_datetime  passenger_count  \
# 0        id2875421          2 2016-03-14 17:24:55                1
# 1        id2377394          1 2016-06-12 00:43:35                1
# 2        id3858529          2 2016-01-19 11:35:24                1
# 3        id3504673          2 2016-04-06 19:32:31                1
# 4        id2181028          2 2016-03-26 13:30:55                1
# ...            ...        ...                 ...              ...
# 1458639  id2376096          2 2016-04-08 13:31:04                4
# 1458640  id1049543          1 2016-01-10 07:35:15                1
# 1458641  id2304944          2 2016-04-22 06:57:41                1
# 1458642  id2714485          1 2016-01-05 15:56:26                1
# 1458643  id1209952          1 2016-04-05 14:44:25                1
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0              -73.982155        40.767937         -73.964630
# ...

# %%
plt.figure(figsize=(10,5))
plt.title('Распределение прологарифмированного таргета в обучающей выборке', fontsize=15)
plt.hist(data_train.log_trip_duration,bins=50, edgecolor='black')
plt.xlabel('Длительность поездки, сек',  fontsize=15)
plt.ylabel('Количество поездок',  fontsize=15)
plt.grid(True)

# %% [markdown]
# **(0.1 балл)** Чтобы иметь некоторую точку отсчета, давайте посчитаем значение метрики MSE при наилучшем константном предсказании:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from sklearn.metrics import mean_squared_error
y_train = data_train.log_trip_duration
best_const = y_train.mean()
mean_squared_error(y_train, best_const * np.ones(y_train.shape), squared=True)
# Out:
# 0.6332327625405546

# %% [markdown]
# ## Часть 1. Изучаем `pickup_datetime` (4 балла)
#
# **Задание 2 (0.5 баллов)**.
#
# **(0.25 баллов)** Для начала давайте посмотрим, сколько всего было поездок в каждый из дней. Постройте график зависимости количества поездок от дня в году (например, можно воспользоваться `sns.countplot`):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

plt.figure(figsize=(20,7))
plt.title('График количества поездок в каждый из дней', fontsize=15)
gr = sns.countplot(x=data_train.pickup_datetime.dt.dayofyear)
gr.set_xticks(range(0,185,5))
gr.set_xticklabels(range(0, 185, 5))
plt.xlabel('День в году', fontsize=15)
plt.ylabel('Количество поездок', fontsize=15)
plt.show()

# %% [markdown]
# Вы, вероятно, заметили, что на графике есть 2 периода с аномально маленькими количествами поездок.
#
# **(0.1 балл**)Вычислите, в какие даты происходили эти скачки вниз и найдите информацию о том, что происходило в эти дни в Нью-Йорке.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
data_train.pickup_datetime.dt.dayofyear.value_counts().iloc[-20:]
# Out:
# 18     7146
# 152    7131
# 165    7114
# 164    7112
# 39     7110
# 178    7084
# 32     7064
# 116    7028
# 149    7004
# 171    6962
# 26     6941
# 172    6910
# 4      6725
# 2      6512
# 150    6372
# 3      6353
# 25     6084
# 151    5570
# 24     3383
# 23     1648
# Name: pickup_datetime, dtype: int64

# %% [markdown]
# Резкий спад наблюдается в 23-24 дни и 150-151 дни года.

# %%
date_23 = data_train.pickup_datetime.loc[data_train.pickup_datetime.dt.dayofyear==23].iloc[0]
date_24 = data_train.pickup_datetime.loc[data_train.pickup_datetime.dt.dayofyear==24].iloc[0]
date_150 = data_train.pickup_datetime.loc[data_train.pickup_datetime.dt.dayofyear==150].iloc[0]
date_151 = data_train.pickup_datetime.loc[data_train.pickup_datetime.dt.dayofyear==151].iloc[0]
date_23, date_24, date_150, date_151
# Out:
# (Timestamp('2016-01-23 08:46:42'),
#  Timestamp('2016-01-24 20:35:19'),
#  Timestamp('2016-05-29 00:15:12'),
#  Timestamp('2016-05-30 13:33:07'))

# %% [markdown]
# 23-24 января 2016 года было приостановлено автомобильное движение в Нью-Йорке из-за сильной метели. https://en.wikipedia.org/wiki/January_2016_United_States_blizzard
#
# 29-30 мая 2016 года проводился праздник Ден Повиновения, некоторые улицы были перекрыты для парадов.
# https://www.theguardian.com/us-news/2016/may/30/jfk-airport-new-york-flight-delays-terminal-7

# %% [markdown]
# **(0.15 баллов)** Нарисуйте графики зависимости количества поездок от дня недели и от часов в сутках (воспользуйтесь `sns.relplot`):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Sunday', 'Saturday']
pickup_datetime = data_train.pickup_datetime.dt.weekday 
pickup_datetime = pickup_datetime.value_counts()
pickup_datetime = pickup_datetime.sort_index()

gr = sns.relplot(x=days, y=pickup_datetime, kind='line')
gr.fig.suptitle('График зависимости количества поездок от дня недели')
gr.set_axis_labels('','Количество поездок', fontsize=15)
gr.fig.set_figwidth(10)
gr.fig.set_figheight(5)

# %%
hour = [i for i in range(24)]
pickup_datetime_hour = data_train.pickup_datetime.dt.hour
pickup_datetime_hour = pickup_datetime_hour.value_counts()
pickup_datetime_hour = pickup_datetime_hour.sort_index()

gr = sns.relplot(x=hour, y=pickup_datetime_hour, kind='line')
gr.fig.suptitle('График зависимости количества поездок от часа в сутках')
plt.xticks(range(24))
gr.set_axis_labels('Час в сутках','Количество поездок', fontsize=15)
gr.fig.set_figwidth(10)
gr.fig.set_figheight(5)

# %% [markdown]
# **Задание 3 (1 балл)**.
#
# * **(0.3 балла)** Нарисуйте на одном графике зависимости количества поездок от часа в сутках для разных месяцев (разные кривые, соответствующие разным месяцам, окрашивайте в разные цвета, воспользуйтесь `hue` в `sns.relplot`).
# * **(0.3 балла)** Аналогично нарисуйте зависимости количества поездок от часа в сутках для разных дней недели.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
month = ['January', 'Febraury', "March","April", "May", "June"]
pickup_datetime =pd.DataFrame(data_train.pickup_datetime)
pickup_datetime.insert(1,value=data_train.pickup_datetime.dt.month_name(), column='month') 
pickup_datetime.month.value_counts()
pickup_datetime.insert(2,value=data_train.pickup_datetime.dt.hour, column='hour') 
pickup_datetime.insert(3,value=data_train.pickup_datetime.dt.day_name(), column='day') 
pickup_datetime_1 = pickup_datetime.groupby(['month', 'hour']).count()

gr = sns.relplot(y =pickup_datetime_1.iloc[:, -2], x='hour', hue='month', hue_order=month, data=pickup_datetime_1, 
                 kind='line', palette='Paired')
gr.fig.suptitle('График зависимости количества поездок от часа в сутках для каждого месяца')
plt.xticks(range(24))
gr.set_axis_labels('Час в сутках','Количество поездок', fontsize=15)
gr.fig.set_figwidth(10)
gr.fig.set_figheight(5)

# %%
pickup_datetime_2 = pickup_datetime.groupby(['day', 'hour']).count()
weekdays=['Monday', "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

gr = sns.relplot(y=pickup_datetime_2.iloc[:, -2], x='hour', hue='day', hue_order=weekdays,
                 data=pickup_datetime_2, kind='line', palette='Paired')
gr.fig.suptitle('График зависимости количества поездок от часа в сутках для каждого дня недели')
plt.xticks(range(24))
gr.set_axis_labels('','Количество поездок', fontsize=15)
gr.fig.set_figwidth(10)
gr.fig.set_figheight(5)

# %% [markdown]
# **Вопрос  (0.4 балла)**: **(?)** Какие выводы можно сделать, основываясь на графиках выше? Выделяются ли какие-нибудь дни недели? Месяца? Время суток? С чем это связано?

# %% [markdown]
# **Ответ**:
# Из графиков можно сделать вывод, что больше всего люди предпочитают поездки по пятницам, а в воскресенье предпочитают оставаться дома. Ночью с 00 до 5 утра поездок очень мало(ночью люди спят), с 5 до 8 утра заметен резкий рост колиечества поездок(люди едут на работу). С 16 до 18 снова рост количества поездок(люди возвращаются с работы), далее спрос на такси падает. На графике зависимости количества поездок от часа заметно, что график для июня днём (с 14 до 20) чуть ниже остальных. Возможно это связано с тем, что летом многие люди предпочитают ходить пешком. А зимой в январе наоборот люди предпочитают посидеть дома и не выходить на прогулку, поэтому график для января также заметно ниже остальных. На графике зависимости количества поездок от часа в сутках для каждого дня недели видно, что в воскресенье вечером (с 17 до 23) спрос на такси намного меньше, чем в другие дни недели. В субботу и воскресенье люди не работают, поэтому утром (с 5 до 10) количество поездок на такси намного меньше, чем в остальные дни. Также можно заметить, что ночью (с 0 до 5) количество поездок по пятницам, субботам и воскресенье больше, но в субботу и воскресенье особенно много. Причем в это время количество поездок с понедельника по пятницу убывает параболически, а в субботу и воскресенье линейно. Также хочется отметить, что в 5 утра спрос на такси в каждый из дней недели почти одинаков.

# %% [markdown]
# **Задание 4 (1 балл)**.
#
# **(0.1 балл) за каждый пункт**
# * Разбейте выборку на обучающую и тестовую в отношении 7:3.
# * По обучающей выборке нарисуйте график зависимости среднего логарифма времени поездки от дня недели.
# * Затем сделайте то же самое, но для часа в сутках и дня в году.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_train, y_train, test_size=3/10, random_state=10)

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

X_train_new = X_train.log_trip_duration.groupby(X_train.pickup_datetime.dt.weekday)

plt.figure(figsize=(13,20))
plt.subplot(3, 1, 1) 
X_train_new = X_train.log_trip_duration.groupby(X_train.pickup_datetime.dt.weekday)
plt.title('График зависимости среднего логарифма времени поездки от дня недели',fontsize=15)
plt.plot(range(7), X_train_new.mean())
plt.grid(True) 
plt.ylabel('Значение среднего логарифма времени',  fontsize=15)
plt.xlabel('День недели',  fontsize=15)
plt.xticks(range(7), ['Понедельник', "Вторник", "Среда", "Четверг", "пятница", "Суббота", "Воскресенье"])

plt.subplot(3, 1, 2) 
X_train_new = X_train.log_trip_duration.groupby(X_train.pickup_datetime.dt.hour)

plt.title('График зависимости среднего логарифма времени поездки от времени суток',fontsize=15)
plt.plot(range(24), X_train_new.mean())
plt.grid(True) 
plt.ylabel('Значение среднего логарифма времени',  fontsize=15)
plt.xlabel('Время суток',  fontsize=15)
plt.xticks(range(24))

plt.subplot(3, 1, 3) 
X_train_new = X_train.log_trip_duration.groupby(X_train.pickup_datetime.dt.day_of_year)
plt.xlabel('День в году',  fontsize=15)
plt.title('График зависимости среднего логарифма времени поездки от дня в году',fontsize=15)
plt.plot(X_train_new.mean())
plt.grid(True) 
plt.ylabel('Значение среднего логарифма времени',  fontsize=15)
plt.xticks(range(0,190, 5))

plt.show()

# %% [markdown]
# **Вопрос (0.3 балла)**: **(?)**Похожи ли графики зависимости таргета от дня недели и от часа в сутках на аналогичные графики для количества поездок? Почему? Что происходит со средним таргетом в те два аномальных периода, что мы видели выше? Почему так происходит? Наблюдаете ли вы какой-нибудь тренд на графике зависимости `log_trip_duration` от номера дня в году?

# %% [markdown]
# **Ответ**:
# Графики зависимости таргета от дня недели и от часа в сутках на аналогичные графики для количества поездок похожи. Оба они где-то постепенно возрастают и убывают, резких скачков нет. Время поездки сильно зависит от пробок, поэтому в будние дни время поездок больше, чем в выходные. Тоже самое можно сказать про график зависимости от часа в сутках. в рабочее время время поездки занимает больше, а ночью время поездки меньше. График зависимости от дня в год сильно изрезан в отличии от предыдущих графиков, на нём много изломов. Заметно, что сначала график резко растёт, а потом резко падает. Скорее всего это связанно с тем, что в по выходным время поездки меньше, а пик времени приходится по четвергам. То есть на эттом графике много раз подряд нарисованы графики зависимости таргета от дня недели. Можно заметить, что в аномальне дни (23-24 и 150-151 дни) график имеет дополнительный изрез, чего не наблюдается на остальных неделях года.

# %% [markdown]
# **(0.1 балл)**
# Добавьте следующие признаки на основе `pickup_datetime`:
# 1. День недели
# 2. Месяц
# 3. Час
# 4. Является ли период аномальным (два бинарных признака, соответствующие двум аномальным периодам)
# 5. Номер дня в году

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train.insert(3, 'weekday', X_train.pickup_datetime.dt.weekday)
X_train.insert(3, 'month', X_train.pickup_datetime.dt.month_name())
X_train.insert(3, 'hour', X_train.pickup_datetime.dt.hour)
X_train.insert(3, 'day', X_train.pickup_datetime.dt.day_of_year)
X_train.insert(7, 'anomal_23_24', np.array(X_train.day==23) + np.array(X_train.day==24))
X_train.insert(7, 'anomal_150_151', np.array(X_train.day==150) + np.array(X_train.day==151))

X_test.insert(3, 'weekday', X_test.pickup_datetime.dt.weekday)
X_test.insert(3, 'month', X_test.pickup_datetime.dt.month_name())
X_test.insert(3, 'hour', X_test.pickup_datetime.dt.hour)
X_test.insert(3, 'day', X_test.pickup_datetime.dt.day_of_year)
X_test.insert(7, 'anomal_23_24', np.array(X_test.day==23) + np.array(X_test.day==24))
X_test.insert(7, 'anomal_150_151', np.array(X_test.day==150) + np.array(X_test.day==151))

X_train
# Out:
#                 id  vendor_id     pickup_datetime  day  hour    month  \
# 824746   id2365163          2 2016-03-27 00:25:29   87     0    March
# 645821   id3126187          2 2016-03-18 20:44:12   78    20    March
# 691846   id2588127          2 2016-04-15 18:26:12  106    18    April
# 1147931  id0915715          2 2016-03-24 14:28:34   84    14    March
# 183569   id3758776          1 2016-04-28 13:53:52  119    13    April
# ...            ...        ...                 ...  ...   ...      ...
# 1348317  id2763967          1 2016-05-12 05:16:06  133     5      May
# 1154171  id0853058          1 2016-01-16 19:14:54   16    19  January
# 617841   id2242904          1 2016-03-21 20:11:12   81    20    March
# 1048548  id2558617          1 2016-04-09 09:21:44  100     9    April
# 1393929  id3799449          1 2016-04-27 09:11:19  118     9    April
#
#          weekday  anomal_150_151  anomal_23_24  passenger_count  \
# ...

# %% [markdown]
# Итак, мы уже создали некоторое количество признаков.
#
# **Вопрос (0.3 балла)**: **(?)**Какие из признаков стоит рассматривать как категориальные, а какие - как численные? Почему?

# %% [markdown]
# **Ответ**:
# Такие признаки как час в сутках и день в году стоит рассматривать как численные, так как их сложно отнести к какой-то категории. В каждой категории должны быть свои особенности. Например, в каждый из дней недели график для целевой переменной разный. Также из логических соображений вряд ли наша модель линейно зависит от дня недели или от месяца.

# %% [markdown]
# **Задание 5 (1.5 балла)**. Обучите `Ridge`-регрессию с параметрами по умолчанию, закодировав все категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`. Используйте только признаки, которые мы выделили в этой части задания.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
features_cat = ['anomal_23_24','anomal_150_151', 'weekday','month']
features_num = ['hour', 'day']

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(), features_cat),
    ('scaling', StandardScaler(), features_num)
])
pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train.drop(columns=['log_trip_duration']), y_train)
y_pred = model.predict(X_test.drop(columns=['log_trip_duration']))
print("Test RMSE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSE = 0.6258

# %% [markdown]
# ## Часть 2. Изучаем координаты (3 балла)
# Мы уже очень хорошо изучили данные о времени начала поездки, давайте теперь посмотрим на информацию о координатах начала и конца поездки. Мы подготовили для вас функцию, которая на карте рисует точки начала или конца поездки. Примеры ее вызова вы найдете ниже. Обратите внимание, что в эту функцию мы передаем лишь небольшой кусочек данных, посколько иначе функция будет работать очень долго

# %%
def show_circles_on_map(data, latitude_column, longitude_column, color):
    """
    The function draws map with circles on it.
    The center of the map is the mean of coordinates passed in data.
    
    data: DataFrame that contains columns latitude_column and longitude_column
    latitude_column: string, the name of column for latitude coordinates
    longitude_column: string, the name of column for longitude coordinates
    color: string, the color of circles to be drawn
    """

    location = (data[latitude_column].mean(), data[longitude_column].mean())
    m = folium.Map(location=location)

    for _, row in data.iterrows():
        folium.Circle(
            radius=100,
            location=(row[latitude_column], row[longitude_column]),
            color=color,
            fill_color=color,
            fill=True
        ).add_to(m)

    return m

# %%
show_circles_on_map(data_train.sample(1000), "pickup_latitude", "pickup_longitude", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
show_circles_on_map(data_train.sample(1000), "dropoff_latitude", "dropoff_longitude", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# **Вопрос**: Какие две точки выделяются на карте?

# %% [markdown]
# На карте выделяются аэропорт Ла Гуардия и аэропорт Кеннеди.

# %% [markdown]
# **Задание 6 (0.75 балл)**.
#
# **(0.3 балла)** Как мы все прекрасно помним, $t = s / v_{\text{ср}}$, поэтому очевидно, что самым сильным признаком будет расстояние, которое необходимо проехать. Мы не можем посчитать точное расстояние, которое необходимо преодолеть такси, но мы можем его оценить, посчитав кратчайшее расстояние между точками начала и конца поездки. Чтобы корректно посчитать расстояние между двумя точками на Земле, можно использовать функцию `haversine`. Посчитайте кратчайшее расстояние для объектов и запишите его в колонку `haversine`:

# %%
#pip install haversine

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from haversine import haversine_vector, Unit

haver_train = haversine_vector([(np.array(X_train.pickup_latitude), np.array(X_train.pickup_longitude))], 
                 [(np.array(X_train.dropoff_latitude), np.array(X_train.dropoff_longitude))], Unit.KILOMETERS)
X_train.insert(9, 'haversine', haver_train[0])

haver_test = haversine_vector([(np.array(X_test.pickup_latitude), np.array(X_test.pickup_longitude))], 
                 [(np.array(X_test.dropoff_latitude), np.array(X_test.dropoff_longitude))], Unit.KILOMETERS)
X_test.insert(9, 'haversine', haver_test[0])

X_train.head()
# Out:
#                 id  vendor_id     pickup_datetime  day  hour  month  weekday  \
# 824746   id2365163          2 2016-03-27 00:25:29   87     0  March        6
# 645821   id3126187          2 2016-03-18 20:44:12   78    20  March        4
# 691846   id2588127          2 2016-04-15 18:26:12  106    18  April        4
# 1147931  id0915715          2 2016-03-24 14:28:34   84    14  March        3
# 183569   id3758776          1 2016-04-28 13:53:52  119    13  April        3
#
#          anomal_150_151  anomal_23_24  haversine  passenger_count  \
# 824746            False         False   3.593845                3
# 645821            False         False   4.772780                1
# 691846            False         False   9.514719                2
# 1147931           False         False   1.878367                1
# 183569            False         False   0.684610                1
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %% [markdown]
# **(0.25 балла)** Так как мы предсказываем логарифм времени поездки и хотим, чтобы наши признаки были линейно зависимы с этой целевой переменной, нам нужно логарифмировать расстояние: $\log t = \log s - \log{v_{\text{ср}}}$. Запишите логарифм `haversine` в отдельную колонку:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train.insert(10, 'log_haversine', np.log1p(X_train.haversine))
X_test.insert(10, 'log_haversine', np.log1p(X_test.haversine))

# %% [markdown]
# **(0.2 балла)** Убедимся, что логарифм расстояния лучше коррелирует с нашим таргетом, чем просто расстояние:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train.haversine.corr(X_train.log_trip_duration), X_train.log_haversine.corr(X_train.log_trip_duration)
# Out:
# (0.5655123462943624, 0.7498154158882641)

# %% [markdown]
# **Задание 7 (0.75 балла)**.
#
# **(0.2 балла)** Давайте изучим среднюю скорость движения такси. Посчитайте среднюю скорость для каждого объекта обучающей выборки, разделив `haversine` на `trip_duration`, и нарисуйте гистограмму ее распределения

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
speed = X_train.haversine / (X_train.log_trip_duration/120)
plt.figure(figsize=(10,5))
plt.title('Распределение средней скорости', fontsize=15)
plt.hist(speed, bins=10, edgecolor='black')
plt.xlabel('Скорость, км/ч',  fontsize=15)
plt.ylabel('Количество поездок',  fontsize=15)
plt.grid(True)

# %% [markdown]
# **(0.1 балл)** Как можно видеть по гистограмме, для некоторых объектов у нас получились очень больше значения скоростей. Нарисуйте гистограмму по объектам, для которых значение скорости получилось разумным (например, можно не включать рассмотрение объекты, где скорость больше некоторой квантили):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
mask = (speed < np.quantile(speed, 0.95))
plt.figure(figsize=(10,5))
plt.title('Распределение средней скорости', fontsize=15)
plt.hist(speed[mask], bins=100, edgecolor='black')
plt.xlabel('Скорость, км/ч',  fontsize=15)
plt.ylabel('Количество поездок',  fontsize=15)
plt.grid(True)

# %% [markdown]
# **(0.1 балл)** Для каждой пары (день недели, час суток) посчитайте медиану скоростей. Нарисуйте с помощью `sns.heatmap` график, где по осям будут дни недели и часы, а в качестве значения функции - медиана скорости

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train.insert(11, 'speed', speed)
new_data = X_train[['weekday', 'hour', 'speed']]
new_data = X_train.groupby(['weekday', 'hour'])
new_data = pd.DataFrame({'speed':new_data.speed.median()}).reset_index()
new_data = new_data.pivot('weekday', 'hour', 'speed')

plt.figure(figsize=(12, 9))
plt.title('Медиана скоростей', fontsize=15)
sns.heatmap(new_data, linewidths=.1, cmap='mako',  yticklabels=weekdays)
X_train = X_train.drop('speed',1)

# %% [markdown]
# Не забудьте удалить колонку со значением скорости из данных!
#
# **Вопрос (0.1 балл)**: **(?)** Почему значение скорости нельзя использовать во время обучения?

# %% [markdown]
# **Ответ**:
# Время не зависит линейно от скорости, а имеет обратно пропорциальную зависимость. Такую зависимсоть нельзя приблизить линейно.

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)** Посмотрите внимательно на график и скажите, в какие моменты времени скорость минимальна; максимальна.

# %% [markdown]
# **Ответ**:
# Скорость максимальна в ночное время (23 - 5) и минимальна днём (с 8 до 18).

# %% [markdown]
# **(0.15 балл)** Создайте признаки "поездка совершается в период пробок" и "поездка совершается в период свободных дорог" (естественно, они не должен зависеть от скорости!):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train.insert(11,'traffic_period', np.zeros(len(X_train)))
X_train.loc[(X_train.weekday <= 4) & ( X_train.hour <= 19) & (X_train.hour >= 8), 'traffic_period'] = 1
X_train.insert(11,'no_traffic_period', np.zeros(len(X_train)))
X_train.loc[(X_train.weekday <= 3) & (( X_train.hour <=5) | (X_train.hour >= 22)),'no_traffic_period'] = 1
X_train.loc[(X_train.weekday == 4) & (( X_train.hour <=5) | (X_train.hour >= 23)),'no_traffic_period'] = 1
X_train.loc[(X_train.weekday > 4) & (( X_train.hour <=6) | (X_train.hour >= 23)),'no_traffic_period'] = 1

X_test.insert(11,'traffic_period', np.zeros(len(X_test)))
X_test = X_test[:]
X_test.loc[(X_test.weekday <= 4) & ( X_test.hour <= 19) & (X_test.hour >= 8), 'traffic_period'] = 1
X_test.insert(11,'no_traffic_period', np.zeros(len(X_test)))
X_test.loc[(X_test.weekday <= 3) & (( X_test.hour <=5) | (X_test.hour >= 22)),'no_traffic_period'] = 1
X_test.loc[(X_test.weekday == 4) & (( X_test.hour <=5) | (X_test.hour >= 23)),'no_traffic_period'] = 1
X_test.loc[(X_test.weekday > 4) & (( X_test.hour <=6) |(X_test.hour >= 23)),'no_traffic_period'] = 1

# %% [markdown]
# **Задание 8 (0.25 балла)**.
#
# **(0.05 балла)** Как уже было замечено выше, на карте выделяются две точки вдали от Манхэттена. Для каждой из них добавьте в выборку два признака: началась ли поездка в ней и закончилась ли она в ней.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
lat_Ken_1, log_Ken_1 = ( 40.63960144129356,  -73.80828115960485)
lat_Ken_2, log_Ken_2 = (40.65012725265764,-73.76645834466344)
X_train = X_train[:]
pickup_Kennedy = X_train.pickup_latitude.between(lat_Ken_1, lat_Ken_2, inclusive=True) & X_train.pickup_longitude.between(log_Ken_1, log_Ken_2, inclusive=True)
X_train.insert(16, 'pickup_Kennedy', pickup_Kennedy )
pickup_Kennedy = X_test.pickup_latitude.between(lat_Ken_1, lat_Ken_2, inclusive=True) & X_test.pickup_longitude.between(log_Ken_1, log_Ken_2, inclusive=True)
X_test.insert(16, 'pickup_Kennedy', pickup_Kennedy )

dropoff_Kennedy = X_train.dropoff_latitude.between(lat_Ken_1, lat_Ken_2, inclusive=True) & X_train.dropoff_longitude.between(log_Ken_1, log_Ken_2, inclusive=True)
X_train.insert(16, 'dropoff_Kennedy', dropoff_Kennedy )
dropoff_Kennedy = X_test.dropoff_latitude.between(lat_Ken_1, lat_Ken_2, inclusive=True) & X_test.dropoff_longitude.between(log_Ken_1, log_Ken_2, inclusive=True)
X_test.insert(16, 'dropoff_Kennedy', dropoff_Kennedy )

lat_Lib_1, log_Lib_1 = (40.76657793919928, -73.88872002242614)
lat_Lib_2, log_Lib_2 = (40.78191164929617,-73.85455940841246)
pickup_Liberty = X_train.pickup_latitude.between(lat_Lib_1, lat_Lib_2, inclusive=True) & X_train.pickup_longitude.between(log_Lib_1, log_Lib_2, inclusive=True)
X_train.insert(16, 'pickup_Liberty', pickup_Liberty)
pickup_Liberty = X_test.pickup_latitude.between(lat_Lib_1, lat_Lib_2, inclusive=True) & X_test.pickup_longitude.between(log_Lib_1, log_Lib_2, inclusive=True)
X_test.insert(16, 'pickup_Liberty', pickup_Liberty)

dropoff_Liberty = X_train.dropoff_latitude.between(lat_Lib_1, lat_Lib_2, inclusive=True) & X_train.dropoff_longitude.between(log_Lib_1, log_Lib_2, inclusive=True)
X_train.insert(16, 'dropoff_Liberty', dropoff_Liberty)
dropoff_Liberty = X_test.dropoff_latitude.between(lat_Lib_1, lat_Lib_2, inclusive=True) & X_test.dropoff_longitude.between(log_Lib_1, log_Lib_2, inclusive=True)
X_test.insert(16, 'dropoff_Liberty', dropoff_Liberty)

# %%
m = folium.Map(( 40.640,  -73.779))
folium.PolyLine(locations=[(40.63960144129356,  -73.80828115960485), (40.63960144129356, -73.76645834466344 ),
                    (40.65012725265764, -73.76645834466344), (40.65012725265764, -73.80828115960485 ), 
                           (40.63960144129356,  -73.80828115960485)],
                color='red',
                weight=3,
                opacity=0.8).add_to(m)


folium.PolyLine(locations=[(40.76657793919928,-73.88872002242614), (40.76657793919928, -73.85455940841246 ),
                    (40.7819116492961, -73.85455940841246), (40.7819116492961, -73.88872002242614 ), 
                           (40.76657793919928,-73.88872002242614)],
                color='red',
                weight=3,
                opacity=0.8).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# **(0.1 балл)** Для каждого из созданных признаков нарисуйте "ящик с усами" (`sns.boxplot`) распределения логарифма времени поездки

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
plt.figure(figsize=(10, 10))
plt.title('Распределение логарифма времени поездки в зависимости от разных признаков')
plt.subplot(2,2,1)
ax = sns.boxplot(x="pickup_Liberty", y="log_trip_duration", data=X_train)

plt.subplot(2,2,2)
ax = sns.boxplot(x="dropoff_Liberty", y="log_trip_duration", data=X_train)

plt.subplot(2,2,3)
ax = sns.boxplot(x="pickup_Kennedy", y="log_trip_duration", data=X_train)

plt.subplot(2,2,4)
ax = sns.boxplot(x="dropoff_Kennedy", y="log_trip_duration", data=X_train)

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)** судя по графикам, как вы думаете, хорошими ли получились эти признаки?

# %% [markdown]
# **Ответ**:
# Исходя из графиков больше 50 процентов значений тагрета для каждого значения признака попадают в небольшой интервал (ширина "коробки" небольшая). Также усы у графиков не длинные. Из этого можно сделать вывод, что данные признаки получились хорошими.

# %% [markdown]
# <img src="https://www.dropbox.com/s/xson9nukz5hba7c/map.png?raw=1" align="right" width="20%" style="margin-left: 20px; margin-bottom: 20px">
#
# **Задание 9 (1 балл)**. Сейчас мы почти что не используем сами значения координат. На это есть несколько причин: по отдельности рассматривать широту и долготу не имеет особого смысла, стоит рассматривать их вместе. Во-вторых, понятно, что зависимость между нашим таргетом и координатами не линейная. Чтобы как-то использовать координаты, можно прибегнуть к следующему трюку: обрамим область с наибольшим количеством поездок прямоугольником (как на рисунке). Разобьем этот прямоугольник на ячейки. Каждой точке сопоставим номер ее ячейки, а тем точкам, что не попали ни в одну из ячеек, сопоставим значение -1.
#
# Напишите трансформер, который сначала разбивает показанную на рисунке область на ячейки, а затем создает два признака: номер ячейки, в которой началась поездка, и номер ячейки, в которой закончилась поездка. Количество строк и столбцов выберите самостоятельно.
#
# Обратите внимание, что все вычисления должны быть векторизованными, трансформер не должен модифицировать передаваемую ему выборку inplace, а все необходимые статистики (если они вдруг нужны) нужно считать только по обучающей выборке в методе `fit`:

# %%
def grid(n_lat, n_log):
    m = show_circles_on_map(data_train.sample(1000), "dropoff_latitude", "dropoff_longitude", "blue")
    start_lat = 40.705259746972104 
    stop_lat = 40.81320749557158
    start_log = -74.0204705309494
    stop_log = -73.94425287958221
    
    l_1, step_lat = np.linspace(start_lat, stop_lat, n_lat, retstep=True)
    l_2, step_log = np.linspace(start_log, stop_log, n_log, retstep=True)

    loc = [(40.705259746972104,-74.0204705309494),
           (40.705259746972104,-73.94425287958221),
          (40.81320749557158,-73.94425287958221),
          (40.81320749557158,-74.0204705309494),
          (40.705259746972104,-74.0204705309494)]

    folium.PolyLine(loc,
                    color='red',
                    weight=3,
                    opacity=0.8).add_to(m)
    
    for i in l_1:
        loc=[]
        for j in l_2:
            loc.append((i, j))
        folium.PolyLine(loc,
                        color='red',
                        weight=3,
                        opacity=0.8).add_to(m)
    for j in l_2:
        loc=[]
        for i in l_1:
            loc.append((i, j))
        folium.PolyLine(loc,
                        color='red',
                        weight=3,
                        opacity=0.8).add_to(m)
        
        
#     folium.Circle(
#             radius=100,
#             location=( X_train.iloc[1].pickup_latitude,  X_train.iloc[1].pickup_longitude),
#             color='red',
#             fill_color='red',
#             fill=True).add_to(m)
    
    return m

grid(6,4)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from scipy.spatial.distance import cdist

COL_NAMES = dict(
    pick_lat="pickup_latitude",
    pick_lon="pickup_longitude",
    drop_lat="dropoff_latitude",
    drop_lon="dropoff_longitude"
)


class MapGridTransformer(BaseEstimator, TransformerMixin):
     #╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
    def __init__(self, column_lat, column_log, new_column, n_lat=3, m_log=4):
        self.n = n_lat + 1
        self.m = m_log + 1
        self.lat = column_lat
        self.log = column_log
        self.feature = None
        self.new_column = new_column
        
    def fit(self, X):
        start_lat = 40.705259746972104 
        stop_lat = 40.81320749557158
        start_log = -74.0204705309494
        stop_log = -73.94425287958221
        
        l_1, step_lat = np.linspace(start_lat, stop_lat, self.n, retstep=True)
        l_2, step_log = np.linspace(start_log, stop_log, self.m, retstep=True)
        new_feature=np.zeros(len(X))
        k = 1
        for i in l_1:
            for j in l_2:
                if j!=stop_log and i!=stop_lat:
                    new_feature += (X.loc[:, self.lat].between(i, i+step_lat, inclusive='left') &\
                                X.loc[:, self.log].between(j, j+step_log, inclusive='left'))*k
                    k += 1
        new_feature[new_feature == 0] = -1
        self.feature = new_feature

    def transform(self, X):
        X = X[:]
        X.loc[:, self.new_column] = self.feature
        return X

# %%
n=5
m=3

a = MapGridTransformer( 'pickup_latitude', 'pickup_longitude', 'pickup_box', n, m)
a.fit(X_train)
X_train = X_train[:]
X_train = a.transform(X_train)

a = MapGridTransformer( 'pickup_latitude', 'pickup_longitude', 'pickup_box', n, m)
a.fit(X_test)
X_test = a.transform(X_test)

a = MapGridTransformer( 'dropoff_latitude', 'dropoff_longitude', 'dropoff_box', n, m)
a.fit(X_train)
X_train = a.transform(X_train)

X_test=X_test[:]
a = MapGridTransformer( 'dropoff_latitude', 'dropoff_longitude', 'dropoff_box', n, m)
a.fit(X_test)
X_test = a.transform(X_test)

# %% [markdown]
# **Задание 10 (0.25 балла)**. Обучите `Ridge`-регрессию со стандартными параметрами на признаках, которые мы выделили к текущему моменту, закодировав категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
features_cat = ['anomal_23_24','anomal_150_151', 'weekday', 'month', 'traffic_period', 'no_traffic_period',
                "pickup_Kennedy","pickup_Liberty", 'dropoff_Kennedy', 'dropoff_Liberty', 'pickup_box', 'dropoff_box' ]
features_num = ['hour', 'log_haversine', 'day']

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(), features_cat),
    ('scaling', StandardScaler(), features_num)
])
pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSE = 0.2265

# %% [markdown]
# ## Часть 3. Изучаем оставшиеся признаки (1 балл)
#
# **Задание 11 (0.75 баллов)**.
#
# У нас осталось еще 3 признака, которые мы не исследовали: `vendor_id`, `passenger_count` и `store_and_fwd_flag`.
#
# **Вопрос (0.1 балл)**: **(?)** Подумайте, почему каждый из этих признаков может быть потенциально полезным.
#
# **Ответ**:
# 'vendor_id' может быть полезен, например, если у одного поставщика постоянно есть какие-то сбои в работе, которые как-то могли повлиять на данные. `store_and_fwd_flag` может указывать на изменение каких-то данных, которые произошли в связи с плохой связью. Можно найти выбросы.

# %% [markdown]
# **(0.1 балл)** Посчитайте, сколько есть уникальных значений у каждого из этих признаков:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
print('vendor_id = ', X_train.vendor_id.unique())
print('passenger_count = ', X_train.passenger_count.unique())
print('store_and_fwd_flag = ', X_train.store_and_fwd_flag.unique())
# Out:
# vendor_id =  [2 1]
# passenger_count =  [3 1 2 6 5 4 0 7 8]
# store_and_fwd_flag =  ['N' 'Y']

# %% [markdown]
# **(0.2 балла)** Постройте "ящики с усами" распределений логарифма времени поездки в зависимости от значений каждого из признаков

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
plt.figure(figsize=(17, 10))
plt.title('Распределение логарифма времени', fontsize=15)
plt.subplot(1,3,1)
ax = sns.boxplot(x="vendor_id", y="log_trip_duration", data=X_train)

plt.subplot(1,3,2)
ax = sns.boxplot(x="passenger_count", y="log_trip_duration", data=X_train)

plt.subplot(1,3,3)
ax = sns.boxplot(x="store_and_fwd_flag", y="log_trip_duration", data=X_train)

# %% [markdown]
# **(0.2 балла)** Переведите признаки `vendor_id` и `store_and_fwd_flag` в значения $\{0;1\}$

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train = X_train[:]
X_train.vendor_id = pd.get_dummies(X_train.vendor_id)
X_train.store_and_fwd_flag = pd.get_dummies(X_train.store_and_fwd_flag)

X_test = X_test[:]
X_test.vendor_id = pd.get_dummies(X_test.vendor_id)
X_test.store_and_fwd_flag = pd.get_dummies(X_test.store_and_fwd_flag)
X_train.head()
# Out:
#                 id  vendor_id     pickup_datetime  day  hour  month  weekday  \
# 824746   id2365163          0 2016-03-27 00:25:29   87     0  March        6
# 645821   id3126187          0 2016-03-18 20:44:12   78    20  March        4
# 691846   id2588127          0 2016-04-15 18:26:12  106    18  April        4
# 1147931  id0915715          0 2016-03-24 14:28:34   84    14  March        3
# 183569   id3758776          1 2016-04-28 13:53:52  119    13  April        3
#
#          anomal_150_151  anomal_23_24  haversine  ...  dropoff_Liberty  \
# 824746            False         False   3.593845  ...            False
# 645821            False         False   4.772780  ...            False
# 691846            False         False   9.514719  ...             True
# 1147931           False         False   1.878367  ...            False
# 183569            False         False   0.684610  ...            False
#
# ...

# %% [markdown]
# **Вопрос (0.15 балла)**: **(?)** Основываясь на графиках выше, как вы думаете, будут ли эти признаки сильными?

# %% [markdown]
# **Ответ**:
# Исходя из графиков эти признаки вряд ли будут сильными. Усы у ящиков очень длинные, это значит, что диапозон значений таргета для каждого значения признака большой. То есть какой-то особенности у данных признаков нет, по этим признакам предсказать время поездки трудно.

# %% [markdown]
# **Задание 12 (0.25 баллов)**. Проверьте свои предположения, обучив модель **в том числе и на этих трех признаках.** Обучайте `Ridge`-регрессию со стандартными параметрами, закодировав  категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
features_cat = [ 'vendor_id']
features_num = ['passenger_count']

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(), features_cat),
    ('scaling', StandardScaler(), features_num)
])
pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSE = 0.6305

# %% [markdown]
# Если признаки не дали какого-то ощутимого улучшения метрики, их можно выбросить из данных.

# %%
X_train = X_train.drop(columns=['store_and_fwd_flag'])
X_test = X_test.drop(columns=['store_and_fwd_flag'])

# %% [markdown]
# ## Часть 4. Улучшаем модель (3 балла)

# %% [markdown]
# **Задание 13 (1 балл)**.
#
# В наших данных есть нетипичные объекты: с аномально маленьким времени поездки, с очень большим пройденным расстоянием или очень большими остатками регрессии. В этом задании предлагается исключить такие объекты из обучающей выборки.
#
#
# **(0.3 балла)** Для этого нарисуйте гистограммы распределения упомянутых выше величин, выберите объекты, которые можно назвать выбросами, и очистите обучающую выборку от них.
#
# Отметим, что хотя эти объекты и выглядят как выбросы, в тестовой выборке тоже скорее всего будут объекты с такими же странными значениями целевой переменной и/или признаков. Поэтому, возможно, чистка обучающей выборки приведёт к ухудшению качества на тесте. Тем не менее, всё равно лучше удалять выбросы из обучения, чтобы модель получалась более разумной и интерпретируемой.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
features_cat = [
                'anomal_23_24', 'anomal_150_151',
                'weekday', 'month', 'traffic_period', 'no_traffic_period',
                "pickup_Kennedy","pickup_Liberty",
                'dropoff_Kennedy', 'dropoff_Liberty', 'pickup_box', 'dropoff_box' , 'vendor_id']
features_num = [ 'log_haversine', 'passenger_count', 'day', 'hour']

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(), features_cat),
    ('scaling', StandardScaler(), features_num)
])
pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])
model = pipeline.fit(X_train, y_train)

plt.figure(figsize=(15,17))
plt.subplot(3, 1, 1)
plt.title('Распределение времени')
plt.hist(X_train.log_trip_duration, bins=100, edgecolor='black')
plt.xlabel('Время, сек',  fontsize=12)
plt.ylabel('Количество поездок',  fontsize=12)
plt.grid(True) 

plt.subplot(3, 1, 2)
plt.title('Распределение логарифма пройденного расстояния')
plt.hist(X_train.log_haversine, bins=100, edgecolor='black')
plt.xlabel('Логарифм расстояния, км',  fontsize=12)
plt.ylabel('Количество поездок',  fontsize=12)
plt.grid(True) 

error = (y_train - model.predict(X_train)) ** 2
plt.subplot(3, 1, 3)
plt.title('Распределение остатка регрессии')
plt.hist(error, bins=50, edgecolor='black')
plt.xlabel('Ошибка',  fontsize=12)
plt.ylabel('Количество поездок',  fontsize=12)
plt.grid(True) 
plt.show()

# %%
X_train.log_trip_duration.sort_values()[-10:]
# Out:
# 1138915    11.366488
# 91717      11.366500
# 1360439    11.366581
# 59891      11.366604
# 295382     11.366650
# 1234291    11.366662
# 355003     14.478063
# 680594     14.533145
# 924150     14.616441
# 978383     15.075755
# Name: log_trip_duration, dtype: float64

# %%
X_train = X_train.loc[X_train.log_trip_duration <= 13]
X_train = X_train.loc[X_train.log_haversine< np.quantile(X_train.log_haversine, 0.95)]

y_train = X_train.log_trip_duration
error = (y_train - model.predict(X_train)) ** 2
mask = (error < np.quantile(error, 0.95))
X_train = X_train[mask]
y_train = X_train.log_trip_duration

# %% [markdown]
# **(0.3 балла)** Сейчас у нас очень много категориальных признаков. В категориальных признаках могут содержаться редкие категории, обычно это плохо: модель сильно переобучается на таких примерах. Попробуйте объединить редкие категории в одну. Естественно, делать это нужно только для действительно редких категорий.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train.pickup_box.value_counts(), X_test.dropoff_box.value_counts(), X_test.pickup_box.value_counts()
# Out:
# ( 8.0     245343
#   5.0     147390
#   12.0     95872
#   4.0      82175
#   9.0      75307
#   1.0      64480
#   11.0     63175
#  -1.0      58233
#   2.0      35517
#   7.0      21154
#   15.0     19666
#   14.0      7956
#   3.0       4191
#   6.0       1028
#   10.0         6
#  Name: pickup_box, dtype: int64,
#   8.0     103968
#   5.0      59970
#  -1.0      59041
#   12.0     44288
#   4.0      32351
#   9.0      31940
#   1.0      28436
#   11.0     28340
#   2.0      15368
#   7.0      12345
#   15.0     11860
#   3.0       4147
#   14.0      3825
#   6.0       1680
#   10.0        30
#   13.0         5
#  Name: dropoff_box, dtype: int64,
#   8.0     114344
#   5.0      68131
#   12.0     43731
#  -1.0      39104
#   4.0      37799
#   9.0      34873
#   1.0      29671
#   11.0     28496
#   2.0      16361
#   7.0       9960
#   15.0      9061
#   14.0      3657
#   3.0       1885
#   6.0        515
#   10.0         6
#  Name: pickup_box, dtype: int64)

# %%
X_train = X_train[:]
X_train.loc[X_train.pickup_box == 13, 'pickup_box'] = 14
X_train.loc[X_train.dropoff_box == 13, 'dropoff_box'] = 14

X_test.loc[X_test.pickup_box == 13, 'pickup_box'] = 14
X_test.loc[X_test.dropoff_box == 13, 'dropoff_box'] = 14

X_train.loc[X_train.pickup_box == 10, 'pickup_box'] = 14
X_train.loc[X_train.dropoff_box == 10, 'dropoff_box'] = 14

X_test.loc[X_test.pickup_box == 10, 'pickup_box'] = 14
X_test.loc[X_test.dropoff_box == 10, 'dropoff_box'] = 14

# %% [markdown]
# **(0.4 балла)**Обучите модель на очищенных данных и посчитайте качество на тестовой выборке.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
features_cat = [
                'anomal_23_24', 'anomal_150_151',
                'weekday', 'month', 'traffic_period', 'no_traffic_period',
                "pickup_Kennedy","pickup_Liberty",
                'dropoff_Kennedy', 'dropoff_Liberty', 'pickup_box', 'dropoff_box' , 'vendor_id']
features_num = [ 'log_haversine', 'day', 'hour']

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(), features_cat),
    ('scaling', StandardScaler(), features_num)
])
pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSE = 0.2285

# %% [markdown]
# **Задание 14 (1 балл)**.
#
# **(0.1 балл)** После OneHot-кодирования количество признаков в нашем датасете сильно возрастает. Посчитайте колиество признаков до и после кодирования категориальных признаков.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

print("Size before OneHot:", X_train.shape)
print("Size after OneHot:", column_transformer.transform(X_train).shape)
# Out:
# Size before OneHot: (921493, 25)
# Size after OneHot: (921493, 62)

# %% [markdown]
# **(0.2 балла)** Попробуйте обучить не `Ridge`-, а `Lasso`-регрессию. **(?)** Какой метод лучше?

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
features_cat = [
                'anomal_23_24', 'anomal_150_151',
                'weekday', 'month', 'traffic_period', 'no_traffic_period',
                "pickup_Kennedy","pickup_Liberty",
                'dropoff_Kennedy', 'dropoff_Liberty', 'pickup_box', 'dropoff_box' , 'vendor_id']
features_num = [ 'log_haversine', 'day', 'hour',  'passenger_count']

from sklearn.linear_model import Lasso

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(), features_cat),
    ('scaling', StandardScaler(), features_num)
])
pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Lasso())
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSE = 0.6324

# %% [markdown]
# **Ответ**:
# Ridge регрессия лучше Lasso примерно в 3 раза. Значит в методе Lasso модель сильно переобучается, в отличие от Ridge.

# %% [markdown]
# **(0.5 балла)** Разбейте обучающую выборку на обучающую и валидационную в отношении 8:2. По валидационной выборке подберите оптимальные значения параметра регуляризации (по логарифмической сетке) отдельно для `Ridge` и отдельно для `Lasso`, на тестовой выборке измерьте качество лучшей полученной модели.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from sklearn.model_selection import GridSearchCV
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=2/10, random_state=10)

X_train_trans = column_transformer.transform(X_train)
X_test_trans = column_transformer.transform(X_test)

alphas = np.logspace(-4, 2, 10)
searcher = GridSearchCV(Ridge(), [{"alpha": alphas}], scoring="neg_root_mean_squared_error", cv=10, n_jobs=-1)
searcher.fit(X_train_trans, y_train)

best_alpha_Ridge = searcher.best_params_["alpha"]
print("Best alpha for Ridge = %.4f" % best_alpha_Ridge)

alphas = np.logspace(-4, 2, 10)
searcher = GridSearchCV(Lasso(), [{"alpha": alphas}], scoring="neg_root_mean_squared_error", cv=10, n_jobs=-1)
searcher.fit(X_train_trans, y_train)

best_alpha_Lasso = searcher.best_params_["alpha"]
print("Best alpha for Lasso = %.4f" % best_alpha_Lasso)
# Out:
# Best alpha for Ridge = 0.0001
# Best alpha for Lasso = 0.0001

# %%
column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(), features_cat),
    ('scaling', StandardScaler(), features_num)
])
pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Lasso(best_alpha_Lasso))
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSE for Lasso = %.4f" % mean_squared_error(y_test, y_pred, squared=True))

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge(best_alpha_Ridge))
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSE for Ridge = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSE for Lasso = 0.1151
# Test RMSE for Ridge = 0.1151

# %% [markdown]
# **(0.2 балла)** Для каждого перебранного `alpha` для Lasso посчитайте количество нулевых весов в модели и нарисуйте график зависимости его от `alpha`. **(?)** Как сильно придётся потерять в качестве, если мы хотим с помощью Lasso избавиться хотя бы от половины признаков?

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(), features_cat),
    ('scaling', StandardScaler(), features_num)
])

zero_coef = []

for alpha in alphas:
    pipeline = Pipeline(steps=[
        ('ohe_and_scaling', column_transformer),
        ('regression', Lasso(alpha))
    ])

    model = pipeline.fit(X_train, y_train)
    zero_coef.append((model.named_steps['regression'].coef_ == 0).sum())
    
plt.figure(figsize=(15, 7))
plt.title('График зависимости количества нулевых коэффициентов от alpha',fontsize=15)
plt.plot(alphas, zero_coef)
plt.grid(True) 
plt.xlim(0, 0.03)
plt.xticks(np.linspace(0, 0.03, 20))
plt.yticks([i for i in range(0, 65 ,5)])
plt.ylabel('Количество нулевых коэффициентов',  fontsize=15)
plt.xlabel('Значение параметра',  fontsize=15)
# Out:
# Text(0.5, 0, 'Значение параметра')

# %%
plt.figure(figsize=(15, 7))
plt.title('График зависимости точности модели Lasso от alpha',fontsize=15)
plt.plot(alphas, abs(searcher.cv_results_['mean_test_score']))
plt.grid(True) 
plt.ylim(0.3, 0.4)
plt.xlim(0, 0.03)
plt.xticks(np.linspace(0, 0.03, 20))
plt.ylabel('Среднее значение точности, CVscore',  fontsize=15)
plt.xlabel('Значение параметра',  fontsize=15)
# Out:
# Text(0.5, 0, 'Значение параметра')

# %% [markdown]
# Ошибка при $\alpha = 0.0016$ примерно равна 0.34, что почти на 0.2 больше, чем ошибка модели с лучшим параметром.

# %% [markdown]
# <img src="https://www.dropbox.com/s/wp4jj0599np17lh/map_direction.png?raw=1" width="20%" align="right" style="margin-left: 20px">
#
# **Задание 15 (1 балл + 1 бонус)**.
#
# **(0.7 баллов)** Часто бывает полезным использовать взаимодействия признаков (feature interactions), то есть строить новые признаки на основе уже существующих. Выше мы разбили карту Манхэттена на ячейки и придумали признаки "из какой ячейки началась поездка" и "в какой ячейке закончилась поездка".
#
# Давайте попробуем сделать следующее: посчитаем, сколько раз встречается каждая возможная пара этих признаков в нашем датасете и выберем 100 самых частых пар. Закодируем поездки с этими частыми парами как категориальный признак, остальным объектам припишем -1. Получается, что мы закодировали, откуда и куда должно было ехать такси.
#
# Также можете придумать ещё какой-нибудь способ сделать признаки про маршрут. Если эти признаки будут давать хороший прирост в качестве, то за это могут быть даны дополнительные бонусные баллы **(до 1 бонусного балла)**

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
data = X_train[['pickup_box', 'dropoff_box']]
data.pickup_box = data.pickup_box.astype(int)
data.dropoff_box = data.dropoff_box.astype(int)
data.pickup_box = data.pickup_box.astype(str)
data.dropoff_box = data.dropoff_box.astype(str)
data = data.pickup_box.astype(str) +','+ data.dropoff_box.astype(str)
pairs = data.value_counts()[:100]

X_pairs = X_train.pickup_box.astype(int).astype(str) +','+ X_train.dropoff_box.astype(int).astype(str)
X_train = X_train[:]
X_train.insert(len(X_train.columns),'pair_box', X_pairs.apply(lambda x: str(x) if x in pairs else '-1'))
X_train = X_train[:]

X_pairs = X_test.pickup_box.astype(int).astype(str) +','+ X_test.dropoff_box.astype(int).astype(str)
X_test = X_test[:]
X_test.insert(len(X_test.columns),'pair_box', X_pairs.apply(lambda x: str(x) if x in pairs else -1))
X_test = X_test[:]
X_train
# Out:
#                 id  vendor_id     pickup_datetime  day  hour     month  \
# 1330662  id2530299          1 2016-04-19 22:32:03  110    22     April
# 1076538  id1467168          0 2016-03-04 11:26:52   64    11     March
# 1338538  id1834830          1 2016-02-13 16:51:01   44    16  February
# 196615   id2735735          1 2016-02-04 09:35:11   35     9  February
# 163046   id3950691          0 2016-02-29 20:17:41   60    20  February
# ...            ...        ...                 ...  ...   ...       ...
# 1342039  id0546750          0 2016-04-23 10:33:35  114    10     April
# 1412570  id0466679          1 2016-01-16 13:25:13   16    13   January
# 1083661  id0974112          1 2016-01-28 16:14:37   28    16   January
# 1311451  id1287649          1 2016-03-30 17:12:33   90    17     March
# 885960   id2215182          1 2016-05-28 04:07:54  149     4       May
#
#          weekday  anomal_150_151  anomal_23_24  haversine  ...  \
# ...

# %% [markdown]
# **Вопрос (0.2 балла)**: **(?)** Почему такой признак потенциально полезный? Почему линейная модель не может самостоятельно "вытащить" эту информацию, ведь у нее в распоряжении есть признаки "из какой ячейки началась поездка" и "в какой ячейке закончилась поездка"?

# %% [markdown]
# **Ответ**:
# В линейной модели каждый из двух признаков умножаются на разные коэффициенты, но модель не подбирает коэфифициент для каждой пары, то есть он их не группирует. На выборке с новым признаком модель подберёт коэффициент для каждой пары, поэтому модель должна улучшится.

# %% [markdown]
# **(0.1 балл)** Заново обучите модель `Ridge`, если она дала более высокое качество в предыдущих экспериментах, и `Lasso` иначе) на новых даннных и посчитайте качество на тестовой выборке

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
features_cat = [
                'anomal_23_24', 'anomal_150_151',
                'weekday', 'month', 'traffic_period', 'no_traffic_period',
                "pickup_Kennedy","pickup_Liberty",
                'dropoff_Kennedy', 'dropoff_Liberty', 
                #'pickup_box', 'dropoff_box' ,
                'pair_box',
                'vendor_id']
features_num = [ 'log_haversine', 'day', 'hour',  'passenger_count']

from sklearn.linear_model import Lasso

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown ='ignore'), features_cat),
    ('scaling', StandardScaler(), features_num)
])
pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge(best_alpha_Ridge))
])

model = pipeline.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Test RMSE = %.4f" % mean_squared_error(y_test, y_pred, squared=True))
# Out:
# Test RMSE = 0.1093

# %% [markdown]
# **Задание 16 (бонус, 1 балл)**. Где, как не для нашей задачи, считать манхэттенское расстояние?
#
# **Вопрос (0.2 балла)**: **(?)** Найдите, что такое манхэттенское расстояние и почему оно так называется. Как оно нам может помочь?
#
# **Ответ**:
# Согласно этой метрике, расстояние между двумя точками равно сумме модулей разностей их координат. Метрика так называется, потому что дороги в манхэттене расположены параллельно друг другу, образуя сетку. Расстояние между двумя токами дороги можно вычислить, если двигаться по линиям сетки, также вычиляется манхэттенское расстояние, если рассматривать движение по осям параллельным осям координат.

# %% [markdown]
# **(0.5 балла)** Введите систему координат на нашей карте так, чтобы оси были параллельны улицам Манхэттена, и добавьте сначала в данные признак "манхэттенское расстояние между пунктом отправления и пунктом назначения", а затем и логарифм этого признака. Посчитайте корреляцию между вашим новыми признаком и таргетом; между `log_haversine` и таргетом. В каком случае корреляция больше?
#
# Нарисуйте карту, где покажете выбранные оси. Чтобы мы могли проверить вашу работу, просьба сделать скрин этой карты и приложить картинку (если мы откроем ваш ноутбук, виджеты отображаться не будут).

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
# from scipy.spatial.distance import cityblock
# X_train.loc['manh_dist'] = cityblock(X_train[['pickup_lattitude', 'piskup_logitude']], 
#                                      X_train[['dropoff_lattitude', 'dropoff_logitude']])
# X_train.loc['log_manh_dist'] = np.log1p(X_train.manh_dist)


[[40.76144529722106,-73.96647285943368],[40.80559183723034,-73.93447266534567]]
[[40.76144290676765,-73.98149542972759],[40.7678220075259,-73.96649651691632]]

# %%
m = folium.Map(( 40.640,  -73.779))
folium.PolyLine(locations = [(40.76144529722106,-73.96647285943368), (40.80559183723034,-73.93447266534567) ],
                        color='red',
                        weight=3,
                        opacity=0.8).add_to(m)
folium.PolyLine(locations = [(40.76144529722106,-73.96647285943368), (40.7678923001231,-73.98143105671123) ],
                        color='red',
                        weight=3,
                        opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# x= cos(долгота)*радиус_земли* масштаб + сдвиг участка карты

# y= sin(широта)*радиус_земли* масштаб + сдвиг участка карты
R = 6371
#40.76144529722106,-73.96647285943368
import math as m
x = m.cos(-73.96647285943368)*R
y = m.sin(0.76144529722106)*R
x,y
# Out:
# (883.0071579890042, 4395.788222017048)

# %%
# 40.76657194014494,-73.96697407285724]
x = m.cos(-73.96697407285724)*R -x
y = m.sin(40.76657194014494)*R + y
x,y
# Out:
# (883.0071579890042, -3452.0561426693794)

# %%
X_train.log_manh_dist.corr(X_train.log_trip_duration), X_train.log_haversine.corr(X_train.log_trip_duration)

# %% [markdown]
# **(0.3 балла)** Заново обучите модель на новых даннных и посчитайте качество на тестовой выборке. **(?)** Стало ли лучше? Объясните полученный результат.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **Задание 17 (бонус, 2 балла)**. Реализуйте трансформер, который строит разбиение карты по шестигранной решётке с помощью библиотеки [H3](https://github.com/uber/h3-py) и вычисляет признаки на основе такого разбиения.
#
# Признаки могут быть самые разные: расстояние между точкой старта и финиша, посчитанное в количестве шестиугольников; статистика по числу поездок и по их продолжительности в соседних шестиугольниках.
#
# Важно: производительность библиотеки существенно зависит от количества шестиугольников на карте (определяется параметром resolution). Подберите такое разрешение, при котором ваш код будет работать за приемлемое время.
#
# При построении признаков старайтесь не допустить утечки целевой переменной --- в противном случае хорошего качества на тестовой выборке достичь не получится.
#
# Измерьте качество после добавления новых признаков. За улучшение функционала ошибки на каждые 0.005 на тестовой выборке будет даваться 0.5 бонусных балла. Можно получить до 2 бонусных баллов за это задание.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **Бонус (0.3 балла)** Вставьте картинку, описывающую ваш опыт выполнения этого ДЗ.

# %%
from IPython.display import Image
Image("scale_1200.jpg")

# %% [markdown]
# ссылки
# https://medium.com/analytics-vidhya/root-mean-square-log-error-rmse-vs-rmlse-935c6cc1802a
